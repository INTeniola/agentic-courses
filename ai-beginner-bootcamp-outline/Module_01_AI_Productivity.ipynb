# %% [markdown]
# # Module 01 — AI Tools & Practical Uses
# ### Different AI Tools and What You Can Do With Them
#
# ---

# %% [markdown]
# ## Learning Objectives
# - Set up free AI subscriptions (ChatGPT, Claude, Perplexity).
# - Identify which tool is best for specific tasks.
# - Use AI for writing, research, studying, and designing visuals.
# - Learn the basics of prompting.

# %% [markdown]
# ## The Benefit
# **Reclaiming Time:** You will learn how to use the right tools for the right tasks, effectively saving hours of manual work every week and significantly boosting your personal productivity.

# %% [markdown]
# ## Main Lesson Sections
# ### 1) The Tool Landscape
# - **ChatGPT:** Ideation, brainstorming, and writing.
# - **Claude:** Document analysis, reasoning, and coding.
# - **Perplexity:** Research and finding facts.
# - **Canva:** Simple visual design.
#
# ### 2) Different Things You Can Do
# - Summarizing long PDFs or articles.
# - Generating social media content calendars.
# - Drafting professional emails or reports.
#
# ### 3) Prompting 101
# Formula: **Role + Task + Context + Format**
# Example: *"Act as a marketer. Write a tweet about a new coffee blend. Make it funny. Use bullet points."*

# %% [markdown]
# ## Live Demo Walkthrough
# Watch the facilitator summarize a complex PDF and generate a week of content.

# %% [markdown]
# ## Exercises
# 1. Set up a free account on ChatGPT or Claude.
# 2. Use the Prompting 101 formula to generate an email for work/school.
# 3. Improve the prompt iteratively.

# %% [markdown]
# ## Key Takeaways
# - The right tool makes a huge difference.
# - Prompt quality dictates output quality.

# %%
prompt_example = """
Act as a professional communication assistant.
Write a polite email to a client explaining that their project will be delayed by 2 days.
Tone: Professional, apologetic, yet reassuring.
"""
print(prompt_example)
