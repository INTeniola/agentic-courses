# %% [markdown]
# # Module 04 — Apply AI & Next Steps
# ### Where You Can Work & Opportunities
#
# ---

# %% [markdown]
# ## Learning Objectives
# - Identify where you can work and industries looking for AI skills.
# - Explore opportunities like freelancing, content creation, and AI services.
# - Learn beginner-friendly ways to build a portfolio.

# %% [markdown]
# ## The Benefit
# **Career Growth & Income:** You will discover clear, actionable pathways to turn your new AI knowledge into real-world opportunities, whether you want to start a side hustle, land a new job, or excel in your current role.

# %% [markdown]
# ## Main Lesson Sections
# ### 1) Where You Can Work
# Marketing, Operations, HR, Education, Software. Everyone needs efficiency.
#
# ### 2) Different Opportunities
# - **Freelancing / Content Creation:** Faster delivery, higher quality.
# - **AI-Powered Services:** E.g., CV review, newsletter generation.
# - **Workplace Leverage:** Automating your current job to get promoted.
#
# ### 3) Building a Portfolio
# Start small. Build one automation. Package it. Share it online.

# %% [markdown]
# ## Live Demo
# Creating a simple beginner AI service offer.

# %% [markdown]
# ## Next Steps
# - **Keep learning, keep building:** Practice using Kaggle Notebooks and Google AI Studio APIs.
# - **Google & Kaggle Intensive Courses:**
#   1. **5-Day Gen AI Intensive Course (Self-Paced):** Deep dive into Prompt Engineering, Embeddings, Agents, Domain-Specific LLMs, and MLOps.
#   2. **5-Day AI Agents Intensive (June 15-19, 2026):** Learn "Vibe Coding" to build autonomous 10x agents. Compete in the **Kaggriculture** farming simulation (June 19-30, 2026) to earn Kaggle badges/certificates!
# - **Join Communities:** Engage with others on the Kaggle Discord and Agentic Labs community platforms.

# %% [markdown]
# ## Conclusion & Certification
# Congratulations on completing the 5-Day Bootcamp!

# %%
# Example Pricing Calculator
service_hours = 5
hourly_rate = 10000 # NGN
total_price = service_hours * hourly_rate
print(f'Suggested Package Price: NGN {total_price}')
