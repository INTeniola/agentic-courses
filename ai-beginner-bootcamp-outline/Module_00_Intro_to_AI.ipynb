# %% [markdown]
# # Module 00 — AI Foundations, Prompting & "Vibe Coding"
# ### Natural Language as the New Coding Language
#
# ---

# %% [markdown]
# ## Learning Objectives
# - Explain AI and Large Language Models (LLMs) in simple, non-technical terms.
# - Understand the concept of "Vibe Coding" (natural language as programming).
# - Master prompt engineering fundamentals using the 4-step blueprint.
# - Learn how Temperature parameters control model creativity and logic.

# %% [markdown]
# ## The Benefit
# **Clarity and Confidence:** You will leave this session with a clear understanding of AI, free from confusing jargon. You'll master how to structure prompts to get optimal, reliable results every time.

# %% [markdown]
# ## Main Lesson Sections
# ### 1) What is AI & LLMs?
# Think of a Large Language Model as a highly capable intern that reads, writes, and processes language extremely fast. It operates on prediction, guessing the next most logical word.
#
# ### 2) The Rise of "Vibe Coding"
# Programming is changing. Natural language is becoming the primary interface. Instead of writing code lines manually, you describe what you want in plain English ("vibe coding") and the AI generates the system.
#
# ### 3) Prompting Blueprint
# To get quality results, use the **4-Step Blueprint**:
# - **Role:** Who is the AI acting as?
# - **Task:** What do you want it to do?
# - **Context:** What constraints or background details does it have?
# - **Format:** How should the response look (bullet points, email, markdown)?
#
# ### 4) Fine-Tuning Parameters: Temperature
# Models have dials you can adjust. **Temperature** controls randomness:
# - **Low Temperature (0.0 - 0.2):** Factual, logical, highly predictable (good for code, math, factual research).
# - **High Temperature (0.7 - 1.0):** Creative, random, highly expressive (good for brainstorming, writing stories).

# %% [markdown]
# ## Live Demo
# - Demonstrating prompt variations across ChatGPT, Claude, and Gemini.
# - Observing how changing temperature/parameters changes the output creativity.

# %% [markdown]
# ## Exercises
# 1. Write down a repetitive message or writing task you do weekly.
# 2. Draft a prompt for it using the **Role + Task + Context + Format** formula.
# 3. Test the prompt at low vs. high temperature (or rewrite instructions) and evaluate the difference.

# %% [markdown]
# ## Key Takeaways
# - AI is an assistant, not a source of absolute truth.
# - Structuring prompts mathematically improves output quality.
# - You can control creativity by adjusting temperature settings.

# %% [markdown]
# ## 🚀 Interactive Demo: Prompt Engineering in Action
# Let's see how changing a single variable (`temperature`) affects the AI's output. You don't need to understand all the code right now. Just hit **Run**!

# %%
# 1. Run this cell to simulate calling an AI model
import random

def simulate_ai_response(prompt, temperature):
    responses = [
        "The sky is blue today.", 
        "A vast azure expanse stretches endlessly above.", 
        "Why is the sky blue? Rayleigh scattering!",
        "Blue, blue, electric blue."
    ]
    
    print(f"--- Prompt: '{prompt}' ---")
    print(f"Temperature: {temperature}")
    
    # Higher temperature = more randomness
    if temperature < 0.3:
        print(f"AI Response: {responses[0]}")
    elif temperature < 0.7:
        print(f"AI Response: {responses[1]}")
    else:
        # Pick a random response for high temp
        print(f"AI Response: {random.choice(responses)}")
    print("-" * 30)

# Try changing temperature to 0.1, then try 0.9!
simulate_ai_response("Describe the sky.", temperature=0.2)
simulate_ai_response("Describe the sky.", temperature=0.9)

# %% [markdown]
# ## 📚 Essential Resources
# * **[ChatGPT](https://chatgpt.com)** - OpenAI's foundational model interface.
# * **[Claude](https://claude.ai)** - Anthropic's model, excellent for writing and coding.
# * **[Kaggle Prompting Course](https://www.kaggle.com/learn/intro-to-ai-agents)** - Further reading on prompt engineering techniques.
# * **[Prompt Library](https://prompts.chat/)** - A great repository of useful prompts.
