# %% [markdown]
# # Module 03 — Technical Foundations
# ### Required Tools & Coding Essentials
#
# ---

# %% [markdown]
# ## Learning Objectives
# - Set up required tools: IDEs, Hugging Face, Google AI Studio.
# - Understand coding essentials for AI in Python.
# - Learn what an API is and how it connects apps.

# %% [markdown]
# ## The Benefit
# **Becoming a Builder:** You will demystify the technical side of AI. Instead of just consuming AI products, you will gain the foundational knowledge required to start building your own simple, custom AI solutions.

# %% [markdown]
# # Module 03 — Technical Foundations
# ### Required Tools & Coding Essentials
#
# ---
# ## Learning Objectives
# - Set up required tools: IDEs, Hugging Face, Google AI Studio, and Kaggle.
# - Understand coding essentials for AI in Python.
# - Learn what an API is and how it connects apps.
#
# ## The Benefit
# **Becoming a Builder:** You will demystify the technical side of AI. Instead of just consuming AI products, you will gain the foundational knowledge required to start building your own simple, custom AI solutions.
#
# ## Main Lesson Sections
# ### 1) Required Tools
# - **IDE (VS Code / Jupyter):** Where you write code.
# - **Hugging Face:** The 'app store' for AI models and datasets.
# - **Google AI Studio:** Developer environment to test prompts and get API keys.
# - **Kaggle:** Interactive online coding sandboxes with free GPUs for AI experiments.
#
# ### 2) Python Essentials
# - **Variables:** Storing data.
# - **Logic:** Making decisions (if/else).
# - **Functions:** Reusable actions.
#
# ### 3) What is an API?
# An Application Programming Interface (API) is the messenger that takes your request to a system and returns the response.

# %% [markdown]
# ## Live Demo
# Connecting to Google AI Studio via Gemini API to build a simple Python script, followed by a tour of a Kaggle Notebook environment.

# %% [markdown]
# ## Exercises
# 1. Create a Google AI Studio account and generate an API key.
# 2. Create a Kaggle account, go to Settings, and complete phone verification.
# 3. Launch a Kaggle Notebook and practice calling an API or run the [Kaggle Prompting Fundamentals Codelab](https://www.kaggle.com/learn-guide/5-day-genai).
# 4. Identify what an API would do in a hypothetical app you want to build.

# %%
# Example of calling an API using Python
import requests

# This is a placeholder for a real API call
print('Connecting to Google AI Studio API...')
print('Response: Hello, World!')
