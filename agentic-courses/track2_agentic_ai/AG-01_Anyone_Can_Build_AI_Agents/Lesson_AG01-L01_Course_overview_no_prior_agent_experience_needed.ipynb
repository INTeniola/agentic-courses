# %% [markdown]
# ## 🎯 Learning Objectives
# * Understand the scope and goals of the "Anyone Can Build AI Agents" course.
# * Recognize the growing importance of AI agents in modern automation and software development.
# * Familiarize yourself with the course structure and what to expect in the "Agentic AI & Automation Tools" track.
# * Set up your development environment for subsequent lessons, ensuring basic Python and necessary libraries are installed.

# %% [markdown]
# # Welcome to AG-01: Anyone Can Build AI Agents!
#
# Hello and welcome to the **Agentic AI & Automation Tools** track! You've landed in **AG-01: Anyone Can Build AI Agents**, the foundational course designed to demystify the exciting world of AI agents.
#
# ## Why This Course Matters (Especially in 2026)
#
# In 2026, AI agents are no longer a futuristic concept; they are a rapidly evolving reality transforming how we interact with technology and automate complex workflows. From intelligent personal assistants that manage your schedule across platforms to autonomous systems that optimize business operations, agents are at the forefront of innovation. They represent a paradigm shift from traditional, static software to dynamic, adaptive systems capable of *perceiving*, *reasoning*, and *acting* in complex environments.
#
# This course is your intuitive, **code-optional** gateway into understanding these powerful entities. We'll explore the core components that make an agent tick: perception (how they gather information), reasoning (how they process and decide), action (how they interact with the world), tools (the capabilities they leverage), and memory (how they learn and adapt over time).
#
# ## Course Overview: No Prior Agent Experience Needed
#
# **Lesson ID:** AG01-L01
# **Lesson Title:** Course overview: no prior agent experience needed
#
# This lesson serves as your initial roadmap. We'll set the stage for what you'll learn, why it's relevant, and how this course fits into the broader **Agentic AI & Automation Tools** track. Our primary goal is to make agent building accessible to *everyone*, regardless of your technical background. If you're curious about how AI can automate and enhance workflows, you're in the right place!
#
# By the end of this course, you'll have a solid conceptual understanding and practical skills to start building your own AI agents, ready to tackle real-world challenges.

# %% [markdown]
# ## Setting Up Your Agentic Workspace
#
# While this introductory lesson doesn't require complex coding, setting up your environment now will ensure a smooth journey through the rest of the course. We'll be using Python, the de-facto language for AI and machine learning.
#
# ### Prerequisites:
# *   **Python 3.10+**: We recommend using a modern Python version for compatibility with the latest libraries.
# *   **Internet Connection**: For installing packages and accessing online resources.
#
# ### Recommended Environment:
#
# For the easiest setup, especially if you're new to Python environments, we highly recommend using **Google Colab**. It provides a free, cloud-based Jupyter Notebook environment with most necessary packages pre-installed or easily installable. Simply open this notebook in Colab, and you're ready to go!
#
# If you prefer a local setup, ensure you have Python installed and consider using a virtual environment (`venv` or `conda`) to manage your project dependencies cleanly.
#
# ### Installing Core Libraries
#
# We'll be leveraging several powerful libraries throughout this course. For now, let's install some foundational ones that are common in the agentic AI ecosystem. These include frameworks for building agents and tools, and libraries for interacting with Large Language Models (LLMs).

# %%
# Check your Python version
print("Checking Python version...")
# !python --version

# Upgrade pip to ensure you have the latest package installer
print("\nUpgrading pip...")
# !pip install --upgrade pip

# Install foundational libraries for agent development
# We'll use these in upcoming lessons to build sophisticated agents.
print("\nInstalling core agentic libraries (LangChain, CrewAI, OpenAI)...")
# !pip install "langchain>=0.1.0" "crewai>=0.0.1" "openai>=1.0.0" "python-dotenv>=1.0.0"

print("\nEnvironment setup complete! You are ready to build AI agents.")

# %% [markdown]
# ## Your First Agentic Glimpse: Confirming Readiness
#
# To conclude our introductory lesson and confirm your environment is correctly set up, let's run a simple Python code block. This isn't a full-fledged agent yet, but it will give you a tiny taste of how we'll interact with code and hint at the kind of processing agents perform.

# %%
# Confirming your environment is ready for agentic adventures!
print("Hello, aspiring AI Agent Builder!")
print("Your Python environment is set up and ready for AG-01.")

# A tiny glimpse into what agents do: processing information
def process_simple_input(input_text: str) -> str:
    """
    A placeholder function to simulate an agent's basic processing step.
    In future lessons, this will involve perception, reasoning, and tool use.
    """
    if "agent" in input_text.lower() or "ai" in input_text.lower():
        return f"Acknowledged: '{input_text}'. We'll build powerful agents soon!"
    else:
        return f"Received: '{input_text}'. Get ready to learn about AI agents!"

# Let's try it out with a couple of example inputs
user_query_1 = "I want to learn about AI agents and automation."
agent_response_1 = process_simple_input(user_query_1)
print(f"\nSimulated Agent Response 1: {agent_response_1}")

user_query_2 = "This course looks exciting and I'm ready to start!"
agent_response_2 = process_simple_input(user_query_2)
print(f"Simulated Agent Response 2: {agent_response_2}")

print("\nCongratulations! You've successfully completed your first step into the world of AI agents. Let's continue this journey!")
