# %% [markdown]
# ## 🎯 Learning Objectives
# * Understand the overall scope and core requirements of the Multi-Agent AI Hotel Reservation System project.
# * Familiarize with the high-level architecture and key components of the multi-agent system.
# * Set up the development environment with essential tools and libraries for agentic AI development.
# * Execute a basic 'hello world' agent interaction to confirm environment readiness and foundational setup.

# %% [markdown]
# # Welcome to PRJ-01: Multi-Agent AI System for Hotel Reservations - Project Scoping (PRJ01-L01)
#
# Welcome, AI builders, to the capstone project of the Agentic AI & Automation Tools track! This lesson, PRJ01-L01, marks the beginning of our journey into building a sophisticated multi-agent system for hotel reservations.
#
# ## What to Expect
#
# In this introductory lesson, we will:
#
# 1.  **Define the Problem:** Clearly articulate the challenge of automating hotel reservations with intelligent agents.
# 2.  **System Requirements:** Outline the functional and non-functional requirements for our multi-agent system.
# 3.  **Architecture Walkthrough:** Explore the high-level design, including the intent router, sub-crews, and human approval gates.
# 4.  **Environment Setup:** Get our development environment ready with the necessary tools and libraries.
# 5.  **First Agent Interaction:** Run a simple
