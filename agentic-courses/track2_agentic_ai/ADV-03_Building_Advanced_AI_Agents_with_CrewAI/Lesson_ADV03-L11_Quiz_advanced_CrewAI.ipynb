# %% [markdown]
# ## 🎯 Learning Objectives
# * Assess understanding of advanced CrewAI concepts like hierarchical managers, asynchronous tasks, tool caching, and memory systems.
# * Evaluate the ability to apply these concepts in building robust AI agents.
# * Reinforce knowledge of CrewAI's production-ready features.

# %% [markdown]
# # Quiz: Advanced CrewAI Concepts
#
# This quiz is designed to test your understanding of advanced CrewAI features crucial for building robust, scalable, and efficient AI agent systems in production environments.
#
# ---
#
# ### Question 1: Hierarchical Agent Structures
#
# Which of the following best describes the primary benefit of implementing a hierarchical agent structure in CrewAI for complex, multi-stage workflows?
#
# A) It simplifies individual agent prompt engineering by reducing the complexity of each agent's role.
# B) It enables parallel execution of all tasks simultaneously, regardless of dependencies.
# C) It allows for specialized manager agents to oversee and delegate tasks to sub-crews or worker agents, improving task decomposition, oversight, and scalability.
# D) It eliminates the need for external tool integrations by centralizing all capabilities within the manager agent.
#
# ---
#
# ### Question 2: Asynchronous Task Execution
#
# In CrewAI, when designing a crew for a high-throughput data processing pipeline that involves numerous external API calls, which feature would be most critical for ensuring non-blocking operations and efficient resource utilization?
#
# A) Implementing a `cache_handler` for all tools to prevent redundant API calls.
# B) Leveraging asynchronous task execution with Python's `asyncio` to manage concurrent I/O-bound operations.
# C) Centralizing all agent memory into a single, shared memory instance.
# D) Enforcing strict sequential task assignment to maintain predictable execution order.
#
# ---
#
# ### Question 3: Tool Caching and Agent Memory
#
# Consider a CrewAI agent designed to perform extensive web research, often querying the same or similar information multiple times. To optimize performance, reduce API costs, and ensure agents can recall past findings, which two CrewAI features would you prioritize implementing?
#
# A) Dynamic tool loading and advanced prompt templating.
# B) Hierarchical agent structure and custom callback handlers.
# C) Tool caching (e.g., using a `cache_handler`) and persistent agent memory (`memory=True`).
# D) Observability dashboards and strict input validation for all tasks.
#
# ---
#
# ### Question 4: Production Readiness and Observability
#
# When deploying a CrewAI application to production in 2026, which aspect is most crucial for monitoring agent behavior, debugging issues, understanding execution flow, and ensuring long-term stability and performance?
#
# A) Relying solely on print statements and basic file logging for all operational insights.
# B) Implementing comprehensive observability (structured logging, tracing, metrics) and custom callback handlers for integration with monitoring systems.
# C) Disabling all external tool usage to minimize potential points of failure and simplify debugging.
# D) Manually inspecting agent outputs in a Jupyter Notebook environment during live operation.

# %% [markdown]
# <details>
# <summary>Click to reveal Answers and Explanations</summary>
#
# ---
#
# ### Answer Key and Explanations
#
# **Question 1: Hierarchical Agent Structures**
#
# *   **Correct Answer: C)** It allows for specialized manager agents to oversee and delegate tasks to sub-crews or worker agents, improving task decomposition, oversight, and scalability.
# *   **Explanation:** Hierarchical structures in CrewAI enable a
