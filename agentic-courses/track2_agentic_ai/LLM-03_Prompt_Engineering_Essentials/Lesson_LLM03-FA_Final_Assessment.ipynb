# %% [markdown]
# ## 🎯 Learning Objectives
# * Demonstrate a comprehensive understanding of zero-shot, few-shot, and chain-of-thought prompting techniques.
# * Apply the ReAct (Reasoning and Acting) framework to build intelligent agents capable of interacting with external tools.
# * Design and iterate on robust system and user prompts for various LLM applications.
# * Evaluate prompt effectiveness using systematic approaches and identify areas for improvement.
# * Develop practical, production-ready prompt engineering solutions for complex, multi-step tasks.
# * Mitigate common prompt engineering challenges such as hallucination, bias, and prompt injection.

# %% [markdown]
# # LLM-03 Final Assessment: Prompt Engineering Mastery
#
# Welcome to the final assessment for LLM-03: Prompt Engineering Essentials! This assessment is designed to evaluate your comprehensive understanding and practical application of the advanced prompt engineering techniques covered throughout this course.
#
# As developers and product builders working with LLMs daily, your ability to craft effective, reliable, and secure prompts is paramount. This assessment will challenge you to synthesize your knowledge of:
#
# *   **Zero-shot and Few-shot Prompting**: Leveraging LLMs with minimal or no examples.
# *   **Chain-of-Thought (CoT)**: Guiding LLMs through complex reasoning steps.
# *   **ReAct (Reasoning and Acting)**: Building agents that can reason, plan, and interact with external tools.
# *   **Systematic Prompt Development**: Iterative design, testing, and refinement of prompts.
# *   **Prompt Evaluation**: Metrics and strategies for assessing LLM outputs.
# *   **Mitigation Strategies**: Addressing common LLM limitations like hallucination, bias, and prompt injection.
#
# This assessment is structured into two main parts:
#
# 1.  **Review Questions**: A set of conceptual questions to test your theoretical understanding of key prompt engineering principles.
# 2.  **Capstone Coding Problem**: A practical, hands-on challenge where you will design and implement an LLM-powered agent using ReAct, integrating with mock external tools. This problem simulates a real-world scenario, requiring you to apply best practices in prompt construction, tool definition, and agentic workflow design.
#
# Your solutions should reflect a deep understanding of the course material, demonstrate critical thinking, and showcase your ability to build robust LLM applications ready for the demands of 2026 and beyond. Good luck!

# %% [markdown]
# ## Part 1: Review Questions
#
# Answer the following questions concisely, demonstrating your understanding of the core concepts from LLM-03.
#
# 1.  **Zero-shot vs. Few-shot Prompting**: Explain the fundamental difference between zero-shot and few-shot prompting. Provide a scenario where few-shot prompting would be significantly more beneficial than zero-shot, and justify your choice.
#
# 2.  **Chain-of-Thought (CoT)**: Describe the primary mechanism by which Chain-of-Thought prompting improves LLM performance on complex reasoning tasks. What are its limitations, and how might you address them?
#
# 3.  **ReAct Framework**: Outline the core components and the iterative loop of the ReAct (Reasoning and Acting) framework. How does ReAct enhance an LLM's ability to solve problems compared to a pure CoT approach?
#
# 4.  **Prompt Evaluation**: You've developed a new prompt for extracting structured data from unstructured text. Describe at least three distinct methods or metrics you would use to systematically evaluate its performance and identify areas for improvement. Consider both quantitative and qualitative approaches.
#
# 5.  **Mitigating Prompt Injection**: Explain what prompt injection is and why it's a significant security concern for LLM applications. Propose two distinct strategies or architectural patterns that can help mitigate prompt injection attacks in a production system.
#
# 6.  **System Prompts**: Discuss the critical role of system prompts in modern LLM applications. Provide an example of a system prompt that effectively establishes persona, constraints, and output format for a specific task.
#
# 7.  **Iterative Prompt Development**: Describe a systematic workflow for iteratively developing and refining a prompt for a new task. What are the key steps, and why is an iterative approach crucial for achieving optimal results?

# %% [markdown]
# ## Part 2: Capstone Coding Problem - Intelligent Meeting Assistant
#
# **Scenario:**
#
# Your team at AgenticLabs.ng is developing an advanced AI assistant for corporate users. Your task is to build a core component: an **Intelligent Meeting Assistant** that can process meeting notes/transcripts, identify key information, and interact with external tools to provide comprehensive support. This assistant must leverage the ReAct framework to demonstrate reasoning and acting capabilities.
#
# **Objective:**
#
# Design and implement an LLM-powered agent that can:
#
# 1.  **Summarize** the main discussion points from provided meeting notes.
# 2.  **Extract Action Items** with assigned individuals and deadlines (if present).
# 3.  **Search Past Meetings**: If the user asks about a specific topic discussed previously, the agent should use a `search_past_meetings` tool to retrieve relevant information.
# 4.  **Schedule Follow-up Meetings**: If the user explicitly requests to schedule a follow-up, the agent should use a `schedule_follow_up` tool.
#
# **Requirements:**
#
# *   **ReAct Implementation**: Your solution *must* use the ReAct (Reasoning and Acting) prompting pattern. The LLM should output `Thought`, `Action`, `Observation` steps.
# *   **Tool Definitions**: Define two mock Python functions as external tools:
#     *   `search_past_meetings(query: str) -> str`: Simulates searching a database of historical meeting notes. It should return a string indicating search results or
