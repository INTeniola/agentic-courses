# %% [markdown]
# ## 🎯 Learning Objectives
# * Understand the fundamental building blocks of LangChain: Models, Prompts, Chains, and Memory.
# * Learn how these core abstractions interact to enable sophisticated LLM-powered applications.
# * Implement basic examples of each abstraction using LangChain's modern (2026) API and LangChain Expression Language (LCEL).

# %% [markdown]
# # Core Abstractions in LangChain: Building Blocks for Agentic AI
#
# Welcome to the foundational lesson on LangChain's architecture! To build powerful, agentic AI applications, we first need to understand the core components that LangChain provides. Think of LangChain as a sophisticated LEGO set for AI. Each core abstraction is a specialized, interoperable LEGO brick that you can snap together to create complex structures.
#
# Let's break down these essential bricks:
#
# ## 1. Models: The Brains of the Operation
#
# At the heart of any LLM application is, well, an LLM! LangChain provides a unified interface to interact with various Large Language Models (LLMs), Chat Models, and Embedding Models. These are the
