# %% [markdown]
# ## 🎯 Learning Objectives
# * Demonstrate proficiency in designing and implementing multi-agent systems using CrewAI.
# * Apply advanced CrewAI features such as role-based agent design, inter-agent delegation, and automated crew management.
# * Integrate external tools effectively to enhance agent capabilities and solve real-world problems.
# * Orchestrate complex workflows by defining clear tasks, managing context, and utilizing appropriate process types.
# * Debug and evaluate CrewAI agent interactions and crew execution to ensure desired outcomes.

# %% [markdown]
# ## Final Assessment: Building Your First AI Agent with CrewAI
#
# Welcome to the final assessment for GS-02: Building Your First AI Agent with CrewAI! This assessment is designed to evaluate your comprehensive understanding and practical application of the concepts covered throughout the course.
#
# Over the past lessons, you've learned to design intelligent, role-based agents, orchestrate complex workflows through inter-agent delegation, and manage automated crews using the powerful CrewAI framework. You've explored how to define agent roles, goals, and backstories, integrate external tools, and structure tasks for seamless collaboration.
#
# This assessment consists of two main parts:
#
# 1.  **Review Questions**: A set of theoretical questions to test your foundational knowledge of CrewAI concepts, best practices, and architectural considerations.
# 2.  **Capstone Project**: A practical, hands-on coding challenge where you will design and implement a multi-agent system using CrewAI to solve a realistic problem. This project will require you to apply your skills in agent definition, task orchestration, tool integration, and crew management.
#
# **Goal**: By successfully completing this assessment, you will demonstrate your ability to independently conceptualize, build, and debug sophisticated AI agent systems, preparing you for more advanced agentic AI development.
#
# Good luck!

# %% [markdown]
# ### Part 1: Review Questions
#
# Answer the following questions concisely, demonstrating your understanding of CrewAI principles and practices.
#
# 1.  **Agent Components**: What are the four primary components required to define a `crewai.Agent`? Briefly explain the purpose of each.
# 2.  **Process Types**: Differentiate between `sequential` and `hierarchical` process types in CrewAI. Provide a scenario where each would be the more appropriate choice.
# 3.  **Tool Integration**: How do `Tools` enhance an agent's capabilities? Describe how you would integrate a custom Python function as a tool for a CrewAI agent.
# 4.  **Delegation and Context**: Explain the concept of `delegation` in CrewAI. How does the `context` parameter in a `Task` facilitate effective delegation and information flow between agents?
# 5.  **Debugging Crews**: What are the different `verbose` levels available in CrewAI, and how can they be utilized to debug complex agent interactions and task execution?
# 6.  **Task Definition**: Why is it crucial to define clear, specific `description` and `expected_output` for each `Task`? How do these attributes guide agent behavior?
# 7.  **LLM Integration (2026 Perspective)**: In 2026, with the proliferation of diverse LLMs (including local and fine-tuned models), how would you configure a CrewAI agent to use a specific, non-OpenAI LLM provider (e.g., a custom `ollama` instance or a proprietary API)?
# 8.  **Best Practices**: List at least three best practices for designing robust, efficient, and maintainable CrewAI crews, particularly for production environments.

# %% [markdown]
# ### Part 2: Capstone Project - AI-Powered Content Creation & Optimization Crew
#
# **Scenario**: Your task is to build an AI-powered content creation and optimization crew. This crew will research a trending topic, generate a comprehensive article outline, write the article, and then optimize it for search engines (SEO).
#
# **Goal**: Produce a high-quality, SEO-optimized blog post on a user-specified trending topic.
#
# **Requirements**:
#
# 1.  **Agents**: Define at least four distinct agents with clear `role`, `goal`, and `backstory`:
#     *   **Market Research Analyst**: Responsible for identifying trending topics and key search terms.
#     *   **Content Strategist**: Responsible for creating a detailed article outline based on research.
#     *   **Article Writer**: Responsible for writing the full article based on the outline.
#     *   **SEO Optimizer**: Responsible for reviewing and optimizing the article for SEO best practices.
#
# 2.  **Tools**: Integrate at least one external tool. A search tool (e.g., `SerperDevTool` or a similar web search API wrapper) is highly recommended for the Market Research Analyst.
#
# 3.  **Tasks**: Define a sequence of tasks that demonstrate effective delegation and context passing:
#     *   **Task 1 (Research)**: Market Research Analyst identifies 3-5 trending sub-topics/keywords related to the main topic.
#     *   **Task 2 (Outline)**: Content Strategist creates a detailed article outline (sections, sub-sections, key points) using the research findings.
#     *   **Task 3 (Writing)**: Article Writer drafts the full article based on the outline.
#     *   **Task 4 (SEO Optimization)**: SEO Optimizer reviews the drafted article, suggests improvements for keywords, readability, and structure, and outputs the final, optimized article.
#
# 4.  **Crew**: Instantiate a `Crew` with a `hierarchical` process, ensuring agents can delegate and collaborate effectively.
#
# 5.  **Execution**: Run the crew with a user-defined input (e.g., `topic=
