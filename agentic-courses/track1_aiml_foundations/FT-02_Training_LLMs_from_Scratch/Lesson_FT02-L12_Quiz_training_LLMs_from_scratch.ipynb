# %% [markdown]
# ## 🎯 Learning Objectives
# * Assess understanding of pretraining data pipeline considerations for LLMs.
# * Evaluate knowledge of modern LLM architectural components and their benefits.
# * Test comprehension of distributed training strategies for large-scale LLMs.
# * Verify familiarity with advanced post-training alignment techniques and their advantages.

# %% [markdown]
# # Quiz: Training LLMs from Scratch
#
# Welcome to the comprehensive quiz for the 'Training LLMs from Scratch' course! This assessment is designed to test your in-depth understanding of the entire LLM lifecycle, from data preparation and architectural choices to distributed training and post-training alignment. As senior ML engineers and researchers, you're expected to demonstrate a nuanced grasp of these complex topics.
#
# Take your time to answer each question thoroughly. Good luck!
#
# ---
#
# ### Question 1: Pretraining Data Quality
#
# Describe at least three advanced techniques used in 2026 to ensure high-quality and diverse data for LLM pretraining, beyond simple deduplication. Explain why each technique is crucial for modern LLMs.
#
# ---
#
# ### Question 2: Modern LLM Architecture
#
# Explain the architectural advantages of using SwiGLU (or Gated Linear Unit) activation functions over traditional GELU or ReLU in modern large language models. How does it contribute to model performance and efficiency?
#
# ---
#
# ### Question 3: Distributed Training Optimization
#
# You are tasked with training a 70B parameter LLM on a cluster of 64 A100 GPUs. Compare and contrast the memory optimization strategies of Fully Sharded Data Parallel (FSDP) and DeepSpeed ZeRO-3. Under what specific conditions might one be preferred over the other for this scale and hardware configuration?
#
# ---
#
# ### Question 4: Post-training Alignment
#
# Direct Preference Optimization (DPO) has gained significant traction as an alternative to traditional Reinforcement Learning from Human Feedback (RLHF). Explain the core principle of DPO and articulate at least two key advantages it offers over PPO-based RLHF for aligning LLMs.

# %% [markdown]
# <details>
# <summary>Click to reveal Answers and Explanations</summary>
#
# ---
#
# ### Answer 1: Pretraining Data Quality
#
# Beyond basic deduplication, advanced techniques for high-quality and diverse LLM pretraining data in 2026 include:
#
# 1.  **Perplexity-based Filtering with Small Language Models (SLMs):**
#     *   **Description:** Instead of relying solely on heuristic rules or n-gram statistics, a smaller, pre-trained language model (or even a specialized classifier) is used to compute the perplexity of text segments. High-perplexity text (relative to a clean corpus) or text with unusual perplexity patterns (e.g., very low perplexity indicating boilerplate) is filtered out. This can also involve training a
