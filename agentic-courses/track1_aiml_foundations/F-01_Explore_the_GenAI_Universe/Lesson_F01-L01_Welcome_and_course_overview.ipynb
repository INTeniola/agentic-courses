# %% [markdown]
# ## 🎯 Learning Objectives
# * Understand the purpose and scope of the "Explore the GenAI Universe" course within the "AI / ML Foundations" track.
# * Identify the target audience and prerequisites for this course.
# * Successfully set up and verify the Python environment for subsequent lessons.
# * Execute a basic Python command within the Jupyter Notebook environment.

# %% [markdown]
# # Welcome to F-01: Explore the GenAI Universe!
#
# Hello and welcome to the very first lesson of the **AI / ML Foundations** track! You've landed in **F-01: Explore the GenAI Universe**, a course designed to be your broad, accessible introduction to the fascinating world of Generative AI.
#
# ## Course Overview
#
# In this course, we'll embark on a journey to understand:
#
# *   **What Generative AI is:** Moving beyond definitions to grasp its core capabilities.
# *   **How it works (at a high level):** Demystifying the underlying mechanisms without getting lost in complex mathematics initially.
# *   **Where the field stands in 2026:** Exploring the cutting-edge advancements, from multimodal models to enterprise applications, and discussing the ethical considerations that shape its future.
#
# ## Why This Course Matters Now
#
# Generative AI is not just a buzzword; it's a transformative technology reshaping industries, creative processes, and daily life. As of 2026, we're seeing unprecedented adoption across various sectors, with models capable of generating text, images, audio, video, and even code with remarkable fluency. Understanding GenAI is no longer optional; it's a fundamental skill for navigating the modern technological landscape.
#
# ## Who is This Course For?
#
# **Anyone curious about AI!** Seriously, there are no prerequisites. Whether you're a student, a professional looking to upskill, or simply someone intrigued by the headlines, this course is built for you. We'll start from the ground up, ensuring everyone can follow along.
#
# ## How it Fits into the AI / ML Foundations Track
#
# This course serves as your foundational entry point. It provides the essential context and high-level understanding of Generative AI before you dive deeper into specific machine learning concepts, model architectures, or advanced applications in later courses within the track. Think of it as your map to the GenAI universe before you start exploring individual planets.
#
# Let's get started!

# %% [markdown]
# ## Prerequisites and Environment Setup
#
# As mentioned, there are **no prior AI or programming prerequisites** for this course. Your curiosity is the most important tool!
#
# ### Recommended Environment: Google Colab
#
# For this course, we highly recommend using **Google Colaboratory (Colab)**. It's a free, cloud-based Jupyter notebook environment that requires no setup on your part. It comes pre-installed with most of the necessary Python libraries and even offers free access to GPUs, which can be beneficial for more advanced AI tasks later on.
#
# *   **To use Colab:** Simply open this notebook in your browser. If you're viewing this as a static file, click the "Open in Colab" badge (if available) or upload it directly to [Colab](https://colab.research.google.com/).
#
# ### Local Setup (Optional)
#
# If you prefer to run notebooks locally, you'll need:
#
# *   **Python 3.10 or newer:** We recommend using `pyenv` or `conda` for managing Python versions.
# *   **Jupyter Notebook or JupyterLab:** Install via `pip install jupyterlab`.
#
# ### Installing Necessary Libraries
#
# Throughout the course, we'll introduce and install libraries as needed. For this introductory lesson, we'll just ensure our Python environment is ready and install a common utility library (`numpy`) to confirm everything works. We'll use `pip`, the Python package installer.
#
# Run the following code cell to check your Python version and install/upgrade `numpy`.

# %%
# Check Python version
import sys
print(f"Python Version: {sys.version.split(' ')[0]}")

# Upgrade pip to ensure we have the latest package manager
# !pip install --upgrade pip

# Install a common data science library (numpy) to confirm environment is working
# This is a good practice to ensure basic package management is functional.
# !pip install numpy

print("\nEnvironment setup check complete!")
print("You are ready to explore the GenAI Universe!")
