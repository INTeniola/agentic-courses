# %% [markdown]
# ## 🎯 Learning Objectives
# * Understand the scope and importance of Reinforcement Learning in modern AI, particularly for model alignment.
# * Identify the key topics covered in the 'Mastering Reinforcement Learning' course.
# * Verify the development environment setup and essential prerequisites for the course.

# %% [markdown]
# # Welcome to FT-03: Mastering Reinforcement Learning: Foundations to Human Feedback
#
# Welcome, ML engineers, to FT-03, a pivotal course in the AI/ML Foundations track! This course is designed to equip you with a deep understanding of Reinforcement Learning (RL), from its foundational principles to its most advanced applications, including the critical role it plays in aligning modern Large Language Models (LLMs) through Human Feedback (RLHF).
#
# ## Why Reinforcement Learning Matters (Especially in 2026)
#
# In the rapidly evolving landscape of AI, Reinforcement Learning has emerged as a transformative paradigm. Beyond its traditional successes in game playing and robotics, RL is now at the forefront of **model alignment** – ensuring that powerful AI systems behave in ways that are helpful, harmless, and honest. As of 2026, the demand for ML engineers proficient in RL, and specifically RLHF, has skyrocketed, making this skill set indispensable for anyone working on cutting-edge AI development.
#
# This course will bridge the gap between theoretical RL concepts and their practical implementation, focusing on the techniques that are actively shaping the next generation of AI. You'll learn how to design agents that can learn optimal behaviors through interaction with dynamic environments, and critically, how to integrate human preferences into this learning process to create aligned and robust AI systems.
#
# ## Course Overview: Your Journey Ahead
#
# This course is structured to take you on a comprehensive journey through the world of Reinforcement Learning:
#
# 1.  **RL Fundamentals**: We'll start with the core concepts – Markov Decision Processes (MDPs), value functions, policies, and the exploration-exploitation dilemma.
# 2.  **Deep Reinforcement Learning**: We'll then integrate deep neural networks with RL, exploring algorithms like Deep Q-Networks (DQNs) and policy gradient methods.
# 3.  **Advanced Policy Optimization**: A deep dive into state-of-the-art algorithms such as Proximal Policy Optimization (PPO), which is a cornerstone of many modern RL applications.
# 4.  **The RLHF Pipeline**: Finally, we'll unravel the complete Reinforcement Learning from Human Feedback (RLHF) pipeline, understanding how human preferences are collected, modeled, and used to fine-tune LLMs for alignment. This section will cover reward model training, PPO fine-tuning, and practical considerations for deploying aligned models.
#
# By the end of this course, you will not only understand the

# %% [markdown]
# ## Prerequisites and Environment Setup
#
# To ensure a smooth learning experience, please make sure you meet the following prerequisites and set up your development environment as described below.
#
# ### Prerequisites
#
# *   **Python Proficiency**: A strong working knowledge of Python 3.10+ is essential, including object-oriented programming concepts and common data structures.
# *   **Deep Learning Fundamentals**: This course builds directly upon the knowledge gained in **DL-01**. You should be comfortable with neural networks, backpropagation, gradient descent, and working with deep learning frameworks like PyTorch or TensorFlow.
#
# ### Recommended Tools and Libraries (2026 Ready)
#
# We will be using modern, industry-standard libraries and tools throughout this course:
#
# *   **Python 3.10+**: The latest stable versions offer significant performance improvements and syntax enhancements.
# *   **`gymnasium`**: The maintained and extended successor to OpenAI Gym, providing a standard API for RL environments.
# *   **`numpy`**: For numerical operations.
# *   **`torch`**: PyTorch will be our primary deep learning framework due to its flexibility and widespread adoption in RL research.
# *   **`huggingface_hub`**: For interacting with the Hugging Face ecosystem, particularly relevant for RLHF components.
# *   **`jupyter` or `jupyterlab`**: For running these notebooks.
#
# ### Installation Guide
#
# It's highly recommended to use a virtual environment (e.g., `venv` or `conda`) to manage your dependencies.
#
# #### 1. Create and Activate a Virtual Environment (Optional but Recommended)
#
# ```bash
# python -m venv rl_env
# source rl_env/bin/activate  # On Linux/macOS
# rl_env\Scripts\activate    # On Windows
# ```
#
# #### 2. Install Core Libraries
#
# ```bash
# pip install gymnasium numpy torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121  # For CUDA 12.1, adjust for your CUDA version or remove --index-url for CPU only
# pip install huggingface_hub jupyterlab
# ```
#
# *   **Note on PyTorch**: The `--index-url` part is crucial for installing the correct CUDA-enabled PyTorch version. If you don't have a compatible NVIDIA GPU or prefer CPU-only, simply use `pip install torch torchvision torchaudio`. Check the [PyTorch website](https://pytorch.org/get-started/locally/) for the exact command for your system.
#
# #### 3. Verify Installation
#
# After installation, you can run the following code cell to verify that your environment is correctly set up and the core libraries are accessible.

# %%
# Import necessary libraries to verify installation
import gymnasium as gym
import numpy as np
import torch
import huggingface_hub

print(f"Gymnasium version: {gym.__version__}")
print(f"NumPy version: {np.__version__}")
print(f"PyTorch version: {torch.__version__}")
print(f"Hugging Face Hub version: {huggingface_hub.__version__}")

# Check for GPU availability (if PyTorch was installed with CUDA support)
if torch.cuda.is_available():
    print(f"CUDA is available! GPU: {torch.cuda.get_device_name(0)}")
else:
    print("CUDA is not available. PyTorch will run on CPU.")

# --- Basic Gymnasium Environment Test ---
# This demonstrates that gymnasium is correctly installed and can create an environment.
print("\n--- Testing a basic Gymnasium environment ---")

try:
    # Create a classic control environment: CartPole-v1
    # This environment involves balancing a pole on a cart.
    env = gym.make("CartPole-v1")
    print(f"Successfully created environment: {env.spec.id}")

    # Reset the environment to get the initial observation and auxiliary information
    # The observation is the state of the environment (e.g., cart position, pole angle).
    observation, info = env.reset()
    print(f"Initial observation shape: {observation.shape}")
    print(f"Observation space: {env.observation_space}")
    print(f"Action space: {env.action_space}")

    # Take a random action in the environment
    # An action could be moving the cart left or right.
    random_action = env.action_space.sample()
    print(f"Taking random action: {random_action}")

    # Perform a step in the environment with the chosen action
    # This returns the new observation, the reward received, and flags for termination/truncation.
    observation, reward, terminated, truncated, info = env.step(random_action)
    print(f"New observation: {observation}")
    print(f"Reward received: {reward}")
    print(f"Episode terminated: {terminated}")
    print(f"Episode truncated: {truncated}")

    # Close the environment to release resources
    env.close()
    print("Environment test successful!")

except Exception as e:
    print(f"An error occurred during environment test: {e}")
    print("Please ensure gymnasium and its dependencies are correctly installed.")

print("\nEnvironment setup check complete. You are ready to begin your RL journey!")
